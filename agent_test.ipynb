# %%
import pandas as pd 

data = pd.read_csv(r"data/presupuesto_mexico__2020.csv")
# Out:
# c:\Users\luisf\anaconda3\envs\hertie_ra\lib\site-packages\IPython\core\interactiveshell.py:3553: DtypeWarning: Columns (19) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
data.head(5)
# Out:
#    CICLO                               DESC_AI         DESC_CAPITULO  \
# 0   2020  Llevar a cabo el proceso Legislativo  Servicios personales
# 1   2020  Llevar a cabo el proceso Legislativo  Servicios personales
# 2   2020  Llevar a cabo el proceso Legislativo  Servicios personales
# 3   2020  Llevar a cabo el proceso Legislativo  Servicios personales
# 4   2020  Llevar a cabo el proceso Legislativo  Servicios personales
#
#                                        DESC_CONCEPTO            DESC_FF  \
# 0  Remuneraciones al personal de carácter permanente  Recursos fiscales
# 1  Remuneraciones al personal de carácter permanente  Recursos fiscales
# 2  Remuneraciones al personal de carácter permanente  Recursos fiscales
# 3  Remuneraciones al personal de carácter permanente  Recursos fiscales
# 4  Remuneraciones al personal de carácter transit...  Recursos fiscales
#
#   DESC_FUNCION DESC_GPO_FUNCIONAL DESC_MODALIDAD   DESC_PARTIDA_ESPECIFICA  \
# ...

# %%
data.columns
# Out:
# Index(['CICLO', 'DESC_AI', 'DESC_CAPITULO', 'DESC_CONCEPTO', 'DESC_FF',
#        'DESC_FUNCION', 'DESC_GPO_FUNCIONAL', 'DESC_MODALIDAD',
#        'DESC_PARTIDA_ESPECIFICA', 'DESC_PARTIDA_GENERICA', 'DESC_PP',
#        'DESC_RAMO', 'DESC_SUBFUNCION', 'DESC_TIPOGASTO', 'DESC_UR',
#        'ENTIDAD_FEDERATIVA', 'GPO_FUNCIONAL', 'ID_AI', 'ID_CAPITULO',
#        'ID_CLAVE_CARTERA', 'ID_CONCEPTO', 'ID_ENTIDAD_FEDERATIVA', 'ID_FF',
#        'ID_FUNCION', 'ID_MODALIDAD', 'ID_PARTIDA_ESPECIFICA',
#        'ID_PARTIDA_GENERICA', 'ID_PP', 'ID_RAMO', 'ID_SUBFUNCION',
#        'ID_TIPOGASTO', 'ID_UR', 'MONTO_ADEFAS', 'MONTO_APROBADO',
#        'MONTO_DEVENGADO', 'MONTO_EJERCICIO', 'MONTO_EJERCIDO',
#        'MONTO_MODIFICADO', 'MONTO_PAGADO'],
#       dtype='object')

# %% [markdown]
# ### agent with huggingface
# IDEAS: use semantic chunking. Overlapping or recursive text splitting (last one is for structured documents)
# The main thing is to use multimodal data. (Agents can do this)
# Graph based chunking: uses name entity recognition or knowledge graphs.
